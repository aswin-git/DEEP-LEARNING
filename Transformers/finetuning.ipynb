# %%
print('test')
# Out:
# test

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "distilbert-base-uncased"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

print("Model loaded")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
print("Tokenizer OK")
# Out:
# Tokenizer OK

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(
    "prajjwal1/bert-tiny",
    num_labels=2,
    use_safetensors=True,
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at prajjwal1/bert-tiny and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model OK

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("prajjwal1/bert-tiny")
# Out:
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
from datasets import load_dataset

dataset = load_dataset("imdb")  # example

# %%
def tokenize(batch):
    return tokenizer(batch["text"], truncation=True, padding=True)

dataset = dataset.map(tokenize, batched=True)
dataset = dataset.rename_column("label", "labels")
dataset.set_format(type="torch", columns=["input_ids","attention_mask","labels"])
# Out:
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 def tokenize(batch):
#       2     return tokenizer(batch["text"], truncation=True, padding=True)
# ----> 4 dataset = dataset.map(tokenize, batched=True)
#       5 dataset = dataset.rename_column("label", "labels")
#       6 dataset.set_format(type="torch", columns=["input_ids","attention_mask","labels"])
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\dataset_dict.py:953, in DatasetDict.map(self, function, with_indices, with_rank, with_split, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc, try_original_type)
#     950 if with_split:
#     951     function = bind(function, split)
# --> 953 dataset_dict[split] = dataset.map(
#     954     function=function,
#     955     with_indices=with_indices,
#     956     with_rank=with_rank,
#     957     input_columns=input_columns,
#     958     batched=batched,
#     959     batch_size=batch_size,
#     960     drop_last_batch=drop_last_batch,
#     961     remove_columns=remove_columns,
#     962     keep_in_memory=keep_in_memory,
#     963     load_from_cache_file=load_from_cache_file,
#     964     cache_file_name=cache_file_names[split],
#     965     writer_batch_size=writer_batch_size,
#     966     features=features,
#     967     disable_nullable=disable_nullable,
#     968     fn_kwargs=fn_kwargs,
#     969     num_proc=num_proc,
#     970     desc=desc,
#     971     try_original_type=try_original_type,
#     972 )
#     974 if with_split:
#     975     function = function.func
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:562, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     555 self_format = {
#     556     "type": self._format_type,
#     557     "format_kwargs": self._format_kwargs,
#     558     "columns": self._format_columns,
#     559     "output_all_columns": self._output_all_columns,
#     560 }
#     561 # apply actual function
# --> 562 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     563 datasets: list["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     564 # re-apply format to the output
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3341, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc, try_original_type)
#    3339     else:
#    3340         for unprocessed_kwargs in unprocessed_kwargs_per_job:
# -> 3341             for rank, done, content in Dataset._map_single(**unprocessed_kwargs):
#    3342                 check_if_shard_done(rank, done, content)
#    3344 # Avoids PermissionError on Windows (the error: https://github.com/huggingface/datasets/actions/runs/4026734820/jobs/6921621805)
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3697, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, try_original_type)
#    3695 else:
#    3696     _time = time.time()
# -> 3697     for i, batch in iter_outputs(shard_iterable):
#    3698         num_examples_in_batch = len(i)
#    3699         if update_data:
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3647, in Dataset._map_single.<locals>.iter_outputs(shard_iterable)
#    3645 else:
#    3646     for i, example in shard_iterable:
# -> 3647         yield i, apply_function(example, i, offset=offset)
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\datasets\arrow_dataset.py:3570, in Dataset._map_single.<locals>.apply_function(pa_inputs, indices, offset)
#    3568 """Utility to apply the function on a selection of columns."""
#    3569 inputs, fn_args, additional_args, fn_kwargs = prepare_inputs(pa_inputs, indices, offset=offset)
# -> 3570 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3571 return prepare_outputs(pa_inputs, inputs, processed_inputs)
#
# Cell In[10], line 2, in tokenize(batch)
#       1 def tokenize(batch):
# ----> 2     return tokenizer(batch["text"], truncation=True, padding=True)
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:2938, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2936     if not self._in_target_context_manager:
#    2937         self._switch_to_input_mode()
# -> 2938     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2939 if text_target is not None:
#    2940     self._switch_to_target_mode()
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:3026, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3021         raise ValueError(
#    3022             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    3023             f" {len(text_pair)}."
#    3024         )
#    3025     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 3026     return self.batch_encode_plus(
#    3027         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3028         add_special_tokens=add_special_tokens,
#    3029         padding=padding,
#    3030         truncation=truncation,
#    3031         max_length=max_length,
#    3032         stride=stride,
#    3033         is_split_into_words=is_split_into_words,
#    3034         pad_to_multiple_of=pad_to_multiple_of,
#    3035         padding_side=padding_side,
#    3036         return_tensors=return_tensors,
#    3037         return_token_type_ids=return_token_type_ids,
#    3038         return_attention_mask=return_attention_mask,
#    3039         return_overflowing_tokens=return_overflowing_tokens,
#    3040         return_special_tokens_mask=return_special_tokens_mask,
#    3041         return_offsets_mapping=return_offsets_mapping,
#    3042         return_length=return_length,
#    3043         verbose=verbose,
#    3044         split_special_tokens=split_special_tokens,
#    3045         **kwargs,
#    3046     )
#    3047 else:
#    3048     return self.encode_plus(
#    3049         text=text,
#    3050         text_pair=text_pair,
#    (...)
#    3068         **kwargs,
#    3069     )
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:3227, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3217 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3218 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3219     padding=padding,
#    3220     truncation=truncation,
#    (...)
#    3224     **kwargs,
#    3225 )
# -> 3227 return self._batch_encode_plus(
#    3228     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3229     add_special_tokens=add_special_tokens,
#    3230     padding_strategy=padding_strategy,
#    3231     truncation_strategy=truncation_strategy,
#    3232     max_length=max_length,
#    3233     stride=stride,
#    3234     is_split_into_words=is_split_into_words,
#    3235     pad_to_multiple_of=pad_to_multiple_of,
#    3236     padding_side=padding_side,
#    3237     return_tensors=return_tensors,
#    3238     return_token_type_ids=return_token_type_ids,
#    3239     return_attention_mask=return_attention_mask,
#    3240     return_overflowing_tokens=return_overflowing_tokens,
#    3241     return_special_tokens_mask=return_special_tokens_mask,
#    3242     return_offsets_mapping=return_offsets_mapping,
#    3243     return_length=return_length,
#    3244     verbose=verbose,
#    3245     split_special_tokens=split_special_tokens,
#    3246     **kwargs,
#    3247 )
#
# File c:\Users\aswin\anaconda3\Lib\site-packages\transformers\tokenization_utils_fast.py:553, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens)
#     550 if self._tokenizer.encode_special_tokens != split_special_tokens:
#     551     self._tokenizer.encode_special_tokens = split_special_tokens
# --> 553 encodings = self._tokenizer.encode_batch(
#     554     batch_text_or_text_pairs,
#     555     add_special_tokens=add_special_tokens,
#     556     is_pretokenized=is_split_into_words,
#     557 )
#     559 # Convert encoding to dict
#     560 # `Tokens` has type: tuple[
#     561 #                       list[dict[str, list[list[int]]]] or list[dict[str, 2D-Tensor]],
#     562 #                       list[EncodingFast]
#     563 #                    ]
#     564 # with nested dimensions corresponding to batch, overflows, sequence length
#     565 tokens_and_encodings = [
#     566     self._convert_encoding(
#     567         encoding=encoding,
#    (...)
#     576     for encoding in encodings
#     577 ]
#
# KeyboardInterrupt:

# %%
collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
encodings = tokenizer(texts, truncation=True, padding=True, return_tensors="pt")
encodings["labels"] = torch.tensor(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 encodings = tokenizer(texts, truncation=True, padding=True, return_tensors="pt")
#       2 encodings["labels"] = torch.tensor(labels)
#
# NameError: name 'texts' is not defined

# %%
from transformers import Trainer, TrainingArguments
import torch

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_steps=10
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=encodings
)

trainer.train()
